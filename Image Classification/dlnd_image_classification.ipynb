# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 10
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 10:
# Image - Min Value: 4 Max Value: 231
# Image - Shape: (32, 32, 3)
# Label - Label Id: 0 Name: airplane

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
   
        
#     return np.array((x) / (255))
    return (x-x.min())/(x.max()-x.min())


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(np.arange(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """ 
    # TODO: Implement Function
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    return tf.placeholder(tf.float32,shape =(None, image_shape[0],image_shape[1],image_shape[2]),name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape =[None, n_classes],name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """

    # TODO: Implement Function
    channels = x_tensor.get_shape().as_list()[-1]
    shape = [conv_strides[0], conv_strides[1],channels, conv_num_outputs]
    weights =  tf.Variable(tf.truncated_normal(shape, mean=0.0, stddev=0.1))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    convolution = conv2d(x_tensor, weights, biases, conv_strides)
    pooling = maxpool2d(convolution, pool_ksize,pool_strides)
    return pooling

def conv2d(x_tensor, weights, biases, conv_strides):
    x = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0],conv_strides[1], 1], padding = 'SAME')
    x = tf.nn.bias_add(x, biases)
    return tf.nn.relu(x)

def maxpool2d(x_tensor, pool_ksize, pool_strides):
    return tf.nn.max_pool(x_tensor, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0],pool_strides[1], 1], padding='SAME')



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
#     dim = 1
#     for d in x_tensor.get_shape()[1:].as_list():
#         dim *= d
# tf.reshape(x_tensor, shape=[-1, dim])
         
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dim = x_tensor.shape[1].value
    weights = tf.Variable(tf.truncated_normal([dim,  num_outputs], mean=0.0, stddev=0.1))
    biases =  tf.Variable(tf.zeros([num_outputs]))
    fc = tf.reshape(x_tensor, [-1, weights.get_shape().as_list()[0]])
    fc = tf.add(tf.matmul(fc, weights),biases)
    fc = tf.nn.relu(fc)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dim = x_tensor.shape[1].value         
    weights = tf.Variable(tf.truncated_normal([dim,  num_outputs],mean=0.0, stddev=0.1))
    biases =  tf.Variable(tf.zeros([num_outputs]))
    out =  tf.reshape(x_tensor, [-1, weights.get_shape().as_list()[0]])
    out = tf.add(tf.matmul(out, weights), biases)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # Convolution Layer
    
    x_tensor = x
    conv_ksize = (4, 4)
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    
    conv_num_outputs = 64
    conv1 =   conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_num_outputs = 128
    conv2 = conv2d_maxpool(conv1, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_num_outputs = 256
    conv3 = conv2d_maxpool(conv2, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
   
    conv3 = tf.nn.dropout(conv3, keep_prob)
    x_tensor = conv3
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x_tensor = flatten(x_tensor)
    
    num_outputs = 10
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc1 = fully_conn(x_tensor, num_outputs)
    fc1 = tf.nn.dropout(fc1, keep_prob)
    
    
    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    final_output = output(fc1, num_outputs)
    
    
    
    # TODO: return output
    return final_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch,
                                       keep_prob: keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss= sess.run(cost, feed_dict={x: feature_batch,
                                    y: label_batch,
                                     keep_prob: 1.})
    validation_accuracy= sess.run(accuracy, feed_dict={x: valid_features,
                                    y: valid_labels,
                                     keep_prob: 1.})
    print('Loss:{:>10.4f} Validation Accuracy: {:.6f}'.format(loss, validation_accuracy))
   
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = .75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.2493 Validation Accuracy: 0.148200
# Epoch  2, CIFAR-10 Batch 1:  Loss:    2.1525 Validation Accuracy: 0.217000
# Epoch  3, CIFAR-10 Batch 1:  Loss:    2.0667 Validation Accuracy: 0.301800
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.9942 Validation Accuracy: 0.327600
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.9447 Validation Accuracy: 0.342200
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.9221 Validation Accuracy: 0.357400
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.8582 Validation Accuracy: 0.372800
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.8700 Validation Accuracy: 0.375800
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.8173 Validation Accuracy: 0.381800
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.7951 Validation Accuracy: 0.387200
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.8063 Validation Accuracy: 0.385200
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.8055 Validation Accuracy: 0.389000
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.8310 Validation Accuracy: 0.395800
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.7738 Validation Accuracy: 0.396400
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.7295 Validation Accuracy: 0.392200
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.7490 Validation Accuracy: 0.390800
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.7193 Validation Accuracy: 0.394400
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.7477 Validation Accuracy: 0.398400
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.7135 Validation Accuracy: 0.396200
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.6882 Validation Accuracy: 0.404800
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.7043 Validation Accuracy: 0.411600
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.6735 Validation Accuracy: 0.404000
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.6658 Validation Accuracy: 0.402600
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.6554 Validation Accuracy: 0.402800
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.6963 Validation Accuracy: 0.408600
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.6620 Validation Accuracy: 0.405800
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.6493 Validation Accuracy: 0.404800
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.6553 Validation Accuracy: 0.412000
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.6443 Validation Accuracy: 0.409000
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.6239 Validation Accuracy: 0.411000
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.6421 Validation Accuracy: 0.413200
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.6290 Validation Accuracy: 0.414400
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.6468 Validation Accuracy: 0.418600
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.5979 Validation Accuracy: 0.420200
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.6265 Validation Accuracy: 0.418800
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.6271 Validation Accuracy: 0.411600
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.6245 Validation Accuracy: 0.425200
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.5948 Validation Accuracy: 0.424000
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.5933 Validation Accuracy: 0.422400
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.5970 Validation Accuracy: 0.430800
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.5859 Validation Accuracy: 0.440200
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.5904 Validation Accuracy: 0.430600
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.6077 Validation Accuracy: 0.442000
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.5883 Validation Accuracy: 0.440000
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.5989 Validation Accuracy: 0.440000
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.5893 Validation Accuracy: 0.440400
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.5718 Validation Accuracy: 0.440000
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.5617 Validation Accuracy: 0.440800
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.5894 Validation Accuracy: 0.449000
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.5670 Validation Accuracy: 0.448200
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.5816 Validation Accuracy: 0.442600
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.5555 Validation Accuracy: 0.452400
# Epoch 53, CIFAR-10 Batch 1:  Loss:    1.5350 Validation Accuracy: 0.454000
# Epoch 54, CIFAR-10 Batch 1:  Loss:    1.5245 Validation Accuracy: 0.440200
# Epoch 55, CIFAR-10 Batch 1:  Loss:    1.5347 Validation Accuracy: 0.454000
# Epoch 56, CIFAR-10 Batch 1:  Loss:    1.5420 Validation Accuracy: 0.452200
# Epoch 57, CIFAR-10 Batch 1:  Loss:    1.4980 Validation Accuracy: 0.452800
# Epoch 58, CIFAR-10 Batch 1:  Loss:    1.5261 Validation Accuracy: 0.461200
# Epoch 59, CIFAR-10 Batch 1:  Loss:    1.4812 Validation Accuracy: 0.451600
# Epoch 60, CIFAR-10 Batch 1:  Loss:    1.4973 Validation Accuracy: 0.456200
# Epoch 61, CIFAR-10 Batch 1:  Loss:    1.4942 Validation Accuracy: 0.453600
# Epoch 62, CIFAR-10 Batch 1:  Loss:    1.4865 Validation Accuracy: 0.456800
# Epoch 63, CIFAR-10 Batch 1:  Loss:    1.5128 Validation Accuracy: 0.462600
# Epoch 64, CIFAR-10 Batch 1:  Loss:    1.4983 Validation Accuracy: 0.450400
# Epoch 65, CIFAR-10 Batch 1:  Loss:    1.4523 Validation Accuracy: 0.449800
# Epoch 66, CIFAR-10 Batch 1:  Loss:    1.4464 Validation Accuracy: 0.466400
# Epoch 67, CIFAR-10 Batch 1:  Loss:    1.4545 Validation Accuracy: 0.464400
# Epoch 68, CIFAR-10 Batch 1:  Loss:    1.4505 Validation Accuracy: 0.468000
# Epoch 69, CIFAR-10 Batch 1:  Loss:    1.4744 Validation Accuracy: 0.460800
# Epoch 70, CIFAR-10 Batch 1:  Loss:    1.4638 Validation Accuracy: 0.466200
# Epoch 71, CIFAR-10 Batch 1:  Loss:    1.4629 Validation Accuracy: 0.479600
# Epoch 72, CIFAR-10 Batch 1:  Loss:    1.4269 Validation Accuracy: 0.462200
# Epoch 73, CIFAR-10 Batch 1:  Loss:    1.4006 Validation Accuracy: 0.469600
# Epoch 74, CIFAR-10 Batch 1:  Loss:    1.4168 Validation Accuracy: 0.471200
# Epoch 75, CIFAR-10 Batch 1:  Loss:    1.4084 Validation Accuracy: 0.472000
# Epoch 76, CIFAR-10 Batch 1:  Loss:    1.4201 Validation Accuracy: 0.473600
# Epoch 77, CIFAR-10 Batch 1:  Loss:    1.3830 Validation Accuracy: 0.481200
# Epoch 78, CIFAR-10 Batch 1:  Loss:    1.3964 Validation Accuracy: 0.473000
# Epoch 79, CIFAR-10 Batch 1:  Loss:    1.3955 Validation Accuracy: 0.476400
# Epoch 80, CIFAR-10 Batch 1:  Loss:    1.4080 Validation Accuracy: 0.471000
# Epoch 81, CIFAR-10 Batch 1:  Loss:    1.4023 Validation Accuracy: 0.481200
# Epoch 82, CIFAR-10 Batch 1:  Loss:    1.3793 Validation Accuracy: 0.472400
# Epoch 83, CIFAR-10 Batch 1:  Loss:    1.3801 Validation Accuracy: 0.484200
# Epoch 84, CIFAR-10 Batch 1:  Loss:    1.3841 Validation Accuracy: 0.476600
# Epoch 85, CIFAR-10 Batch 1:  Loss:    1.3499 Validation Accuracy: 0.471400
# Epoch 86, CIFAR-10 Batch 1:  Loss:    1.3602 Validation Accuracy: 0.482000
# Epoch 87, CIFAR-10 Batch 1:  Loss:    1.3803 Validation Accuracy: 0.482400
# Epoch 88, CIFAR-10 Batch 1:  Loss:    1.3601 Validation Accuracy: 0.471400
# Epoch 89, CIFAR-10 Batch 1:  Loss:    1.3483 Validation Accuracy: 0.479600
# Epoch 90, CIFAR-10 Batch 1:  Loss:    1.3600 Validation Accuracy: 0.475400
# Epoch 91, CIFAR-10 Batch 1:  Loss:    1.3532 Validation Accuracy: 0.480000
# Epoch 92, CIFAR-10 Batch 1:  Loss:    1.3396 Validation Accuracy: 0.485600
# Epoch 93, CIFAR-10 Batch 1:  Loss:    1.3587 Validation Accuracy: 0.479600
# Epoch 94, CIFAR-10 Batch 1:  Loss:    1.3296 Validation Accuracy: 0.480800
# Epoch 95, CIFAR-10 Batch 1:  Loss:    1.3471 Validation Accuracy: 0.482600
# Epoch 96, CIFAR-10 Batch 1:  Loss:    1.3422 Validation Accuracy: 0.481000
# Epoch 97, CIFAR-10 Batch 1:  Loss:    1.3231 Validation Accuracy: 0.484400
# Epoch 98, CIFAR-10 Batch 1:  Loss:    1.3180 Validation Accuracy: 0.484800
# Epoch 99, CIFAR-10 Batch 1:  Loss:    1.3011 Validation Accuracy: 0.481400
# Epoch 100, CIFAR-10 Batch 1:  Loss:    1.3015 Validation Accuracy: 0.485800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.2527 Validation Accuracy: 0.149800
# Epoch  1, CIFAR-10 Batch 2:  Loss:    1.9645 Validation Accuracy: 0.256600
# Epoch  1, CIFAR-10 Batch 3:  Loss:    1.7615 Validation Accuracy: 0.295600
# Epoch  1, CIFAR-10 Batch 4:  Loss:    1.7497 Validation Accuracy: 0.343800
# Epoch  1, CIFAR-10 Batch 5:  Loss:    1.9238 Validation Accuracy: 0.363600
# Epoch  2, CIFAR-10 Batch 1:  Loss:    1.9488 Validation Accuracy: 0.382200
# Epoch  2, CIFAR-10 Batch 2:  Loss:    1.6875 Validation Accuracy: 0.393600
# Epoch  2, CIFAR-10 Batch 3:  Loss:    1.5689 Validation Accuracy: 0.389800
# Epoch  2, CIFAR-10 Batch 4:  Loss:    1.6176 Validation Accuracy: 0.404000
# Epoch  2, CIFAR-10 Batch 5:  Loss:    1.8066 Validation Accuracy: 0.405200
# Epoch  3, CIFAR-10 Batch 1:  Loss:    1.8814 Validation Accuracy: 0.415000
# Epoch  3, CIFAR-10 Batch 2:  Loss:    1.6212 Validation Accuracy: 0.405800
# Epoch  3, CIFAR-10 Batch 3:  Loss:    1.5247 Validation Accuracy: 0.410600
# Epoch  3, CIFAR-10 Batch 4:  Loss:    1.5466 Validation Accuracy: 0.421800
# Epoch  3, CIFAR-10 Batch 5:  Loss:    1.7367 Validation Accuracy: 0.420600
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.8343 Validation Accuracy: 0.422800
# Epoch  4, CIFAR-10 Batch 2:  Loss:    1.5498 Validation Accuracy: 0.425600
# Epoch  4, CIFAR-10 Batch 3:  Loss:    1.4166 Validation Accuracy: 0.424600
# Epoch  4, CIFAR-10 Batch 4:  Loss:    1.5113 Validation Accuracy: 0.414200
# Epoch  4, CIFAR-10 Batch 5:  Loss:    1.6836 Validation Accuracy: 0.427000
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.7538 Validation Accuracy: 0.433800
# Epoch  5, CIFAR-10 Batch 2:  Loss:    1.4925 Validation Accuracy: 0.436600
# Epoch  5, CIFAR-10 Batch 3:  Loss:    1.3619 Validation Accuracy: 0.436400
# Epoch  5, CIFAR-10 Batch 4:  Loss:    1.4539 Validation Accuracy: 0.433400
# Epoch  5, CIFAR-10 Batch 5:  Loss:    1.6564 Validation Accuracy: 0.443200
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.7399 Validation Accuracy: 0.445200
# Epoch  6, CIFAR-10 Batch 2:  Loss:    1.4800 Validation Accuracy: 0.447600
# Epoch  6, CIFAR-10 Batch 3:  Loss:    1.3611 Validation Accuracy: 0.444800
# Epoch  6, CIFAR-10 Batch 4:  Loss:    1.4375 Validation Accuracy: 0.452400
# Epoch  6, CIFAR-10 Batch 5:  Loss:    1.6251 Validation Accuracy: 0.449800
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.6973 Validation Accuracy: 0.450000
# Epoch  7, CIFAR-10 Batch 2:  Loss:    1.4169 Validation Accuracy: 0.460400
# Epoch  7, CIFAR-10 Batch 3:  Loss:    1.3260 Validation Accuracy: 0.458400
# Epoch  7, CIFAR-10 Batch 4:  Loss:    1.4115 Validation Accuracy: 0.463600
# Epoch  7, CIFAR-10 Batch 5:  Loss:    1.5666 Validation Accuracy: 0.466200
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.6936 Validation Accuracy: 0.463800
# Epoch  8, CIFAR-10 Batch 2:  Loss:    1.4288 Validation Accuracy: 0.447800
# Epoch  8, CIFAR-10 Batch 3:  Loss:    1.3078 Validation Accuracy: 0.463400
# Epoch  8, CIFAR-10 Batch 4:  Loss:    1.3985 Validation Accuracy: 0.468200
# Epoch  8, CIFAR-10 Batch 5:  Loss:    1.5510 Validation Accuracy: 0.461000
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.6177 Validation Accuracy: 0.475200
# Epoch  9, CIFAR-10 Batch 2:  Loss:    1.4202 Validation Accuracy: 0.464400
# Epoch  9, CIFAR-10 Batch 3:  Loss:    1.2838 Validation Accuracy: 0.467200
# Epoch  9, CIFAR-10 Batch 4:  Loss:    1.3615 Validation Accuracy: 0.476600
# Epoch  9, CIFAR-10 Batch 5:  Loss:    1.5168 Validation Accuracy: 0.468800
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.6028 Validation Accuracy: 0.482800
# Epoch 10, CIFAR-10 Batch 2:  Loss:    1.4087 Validation Accuracy: 0.468800
# Epoch 10, CIFAR-10 Batch 3:  Loss:    1.2361 Validation Accuracy: 0.475000
# Epoch 10, CIFAR-10 Batch 4:  Loss:    1.3592 Validation Accuracy: 0.474600
# Epoch 10, CIFAR-10 Batch 5:  Loss:    1.4849 Validation Accuracy: 0.478400
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.5761 Validation Accuracy: 0.484000
# Epoch 11, CIFAR-10 Batch 2:  Loss:    1.3716 Validation Accuracy: 0.472400
# Epoch 11, CIFAR-10 Batch 3:  Loss:    1.2218 Validation Accuracy: 0.490600
# Epoch 11, CIFAR-10 Batch 4:  Loss:    1.3510 Validation Accuracy: 0.485200
# Epoch 11, CIFAR-10 Batch 5:  Loss:    1.4819 Validation Accuracy: 0.485200
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.6071 Validation Accuracy: 0.487200
# Epoch 12, CIFAR-10 Batch 2:  Loss:    1.3373 Validation Accuracy: 0.480600
# Epoch 12, CIFAR-10 Batch 3:  Loss:    1.2170 Validation Accuracy: 0.489800
# Epoch 12, CIFAR-10 Batch 4:  Loss:    1.3361 Validation Accuracy: 0.491400
# Epoch 12, CIFAR-10 Batch 5:  Loss:    1.4708 Validation Accuracy: 0.487000
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.5906 Validation Accuracy: 0.490200
# Epoch 13, CIFAR-10 Batch 2:  Loss:    1.3644 Validation Accuracy: 0.471200
# Epoch 13, CIFAR-10 Batch 3:  Loss:    1.2164 Validation Accuracy: 0.488400
# Epoch 13, CIFAR-10 Batch 4:  Loss:    1.3179 Validation Accuracy: 0.493000
# Epoch 13, CIFAR-10 Batch 5:  Loss:    1.4671 Validation Accuracy: 0.493200
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.5800 Validation Accuracy: 0.496000
# Epoch 14, CIFAR-10 Batch 2:  Loss:    1.3247 Validation Accuracy: 0.480400
# Epoch 14, CIFAR-10 Batch 3:  Loss:    1.2197 Validation Accuracy: 0.496000
# Epoch 14, CIFAR-10 Batch 4:  Loss:    1.3257 Validation Accuracy: 0.488600
# Epoch 14, CIFAR-10 Batch 5:  Loss:    1.4745 Validation Accuracy: 0.487400
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.5593 Validation Accuracy: 0.499000
# Epoch 15, CIFAR-10 Batch 2:  Loss:    1.3469 Validation Accuracy: 0.494000
# Epoch 15, CIFAR-10 Batch 3:  Loss:    1.1999 Validation Accuracy: 0.501200
# Epoch 15, CIFAR-10 Batch 4:  Loss:    1.3036 Validation Accuracy: 0.500800
# Epoch 15, CIFAR-10 Batch 5:  Loss:    1.4696 Validation Accuracy: 0.498200
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.6092 Validation Accuracy: 0.504800
# Epoch 16, CIFAR-10 Batch 2:  Loss:    1.3314 Validation Accuracy: 0.486800
# Epoch 16, CIFAR-10 Batch 3:  Loss:    1.1939 Validation Accuracy: 0.505200
# Epoch 16, CIFAR-10 Batch 4:  Loss:    1.2650 Validation Accuracy: 0.508200
# Epoch 16, CIFAR-10 Batch 5:  Loss:    1.4542 Validation Accuracy: 0.497200
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.5297 Validation Accuracy: 0.508000
# Epoch 17, CIFAR-10 Batch 2:  Loss:    1.3084 Validation Accuracy: 0.488800
# Epoch 17, CIFAR-10 Batch 3:  Loss:    1.1916 Validation Accuracy: 0.500200
# Epoch 17, CIFAR-10 Batch 4:  Loss:    1.2517 Validation Accuracy: 0.511000
# Epoch 17, CIFAR-10 Batch 5:  Loss:    1.4611 Validation Accuracy: 0.501800
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.5291 Validation Accuracy: 0.513000
# Epoch 18, CIFAR-10 Batch 2:  Loss:    1.3378 Validation Accuracy: 0.507800
# Epoch 18, CIFAR-10 Batch 3:  Loss:    1.1975 Validation Accuracy: 0.512400
# Epoch 18, CIFAR-10 Batch 4:  Loss:    1.2555 Validation Accuracy: 0.510000
# Epoch 18, CIFAR-10 Batch 5:  Loss:    1.4407 Validation Accuracy: 0.502600
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.5866 Validation Accuracy: 0.510800
# Epoch 19, CIFAR-10 Batch 2:  Loss:    1.3671 Validation Accuracy: 0.496600
# Epoch 19, CIFAR-10 Batch 3:  Loss:    1.1863 Validation Accuracy: 0.511200
# Epoch 19, CIFAR-10 Batch 4:  Loss:    1.2774 Validation Accuracy: 0.514200
# Epoch 19, CIFAR-10 Batch 5:  Loss:    1.4697 Validation Accuracy: 0.508800
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.5535 Validation Accuracy: 0.512800
# Epoch 20, CIFAR-10 Batch 2:  Loss:    1.3143 Validation Accuracy: 0.506800
# Epoch 20, CIFAR-10 Batch 3:  Loss:    1.1624 Validation Accuracy: 0.514000
# Epoch 20, CIFAR-10 Batch 4:  Loss:    1.2357 Validation Accuracy: 0.515400
# Epoch 20, CIFAR-10 Batch 5:  Loss:    1.4450 Validation Accuracy: 0.511800
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.4824 Validation Accuracy: 0.516200
# Epoch 21, CIFAR-10 Batch 2:  Loss:    1.3184 Validation Accuracy: 0.512000
# Epoch 21, CIFAR-10 Batch 3:  Loss:    1.1722 Validation Accuracy: 0.513800
# Epoch 21, CIFAR-10 Batch 4:  Loss:    1.2185 Validation Accuracy: 0.513800
# Epoch 21, CIFAR-10 Batch 5:  Loss:    1.4517 Validation Accuracy: 0.510800
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.4960 Validation Accuracy: 0.514400
# Epoch 22, CIFAR-10 Batch 2:  Loss:    1.2956 Validation Accuracy: 0.500000
# Epoch 22, CIFAR-10 Batch 3:  Loss:    1.1277 Validation Accuracy: 0.511000
# Epoch 22, CIFAR-10 Batch 4:  Loss:    1.2136 Validation Accuracy: 0.514400
# Epoch 22, CIFAR-10 Batch 5:  Loss:    1.4272 Validation Accuracy: 0.513400
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.4836 Validation Accuracy: 0.521200
# Epoch 23, CIFAR-10 Batch 2:  Loss:    1.3341 Validation Accuracy: 0.504800
# Epoch 23, CIFAR-10 Batch 3:  Loss:    1.1171 Validation Accuracy: 0.515400
# Epoch 23, CIFAR-10 Batch 4:  Loss:    1.2210 Validation Accuracy: 0.521200
# Epoch 23, CIFAR-10 Batch 5:  Loss:    1.4444 Validation Accuracy: 0.513800
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.5021 Validation Accuracy: 0.514000
# Epoch 24, CIFAR-10 Batch 2:  Loss:    1.2532 Validation Accuracy: 0.516600
# Epoch 24, CIFAR-10 Batch 3:  Loss:    1.1219 Validation Accuracy: 0.501600
# Epoch 24, CIFAR-10 Batch 4:  Loss:    1.2511 Validation Accuracy: 0.509600
# Epoch 24, CIFAR-10 Batch 5:  Loss:    1.4336 Validation Accuracy: 0.516600
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.4517 Validation Accuracy: 0.525800
# Epoch 25, CIFAR-10 Batch 2:  Loss:    1.2728 Validation Accuracy: 0.516800
# Epoch 25, CIFAR-10 Batch 3:  Loss:    1.0939 Validation Accuracy: 0.524000
# Epoch 25, CIFAR-10 Batch 4:  Loss:    1.2025 Validation Accuracy: 0.522600
# Epoch 25, CIFAR-10 Batch 5:  Loss:    1.3796 Validation Accuracy: 0.518600
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.5004 Validation Accuracy: 0.523800
# Epoch 26, CIFAR-10 Batch 2:  Loss:    1.2741 Validation Accuracy: 0.520800
# Epoch 26, CIFAR-10 Batch 3:  Loss:    1.0803 Validation Accuracy: 0.526600
# Epoch 26, CIFAR-10 Batch 4:  Loss:    1.2046 Validation Accuracy: 0.519800
# Epoch 26, CIFAR-10 Batch 5:  Loss:    1.4113 Validation Accuracy: 0.521000
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.4272 Validation Accuracy: 0.513200
# Epoch 27, CIFAR-10 Batch 2:  Loss:    1.3210 Validation Accuracy: 0.517200
# Epoch 27, CIFAR-10 Batch 3:  Loss:    1.0798 Validation Accuracy: 0.521200
# Epoch 27, CIFAR-10 Batch 4:  Loss:    1.1875 Validation Accuracy: 0.521800
# Epoch 27, CIFAR-10 Batch 5:  Loss:    1.3803 Validation Accuracy: 0.522600
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.4519 Validation Accuracy: 0.524200
# Epoch 28, CIFAR-10 Batch 2:  Loss:    1.2551 Validation Accuracy: 0.523600
# Epoch 28, CIFAR-10 Batch 3:  Loss:    1.0683 Validation Accuracy: 0.515800
# Epoch 28, CIFAR-10 Batch 4:  Loss:    1.1778 Validation Accuracy: 0.521800
# Epoch 28, CIFAR-10 Batch 5:  Loss:    1.3792 Validation Accuracy: 0.524600
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.3964 Validation Accuracy: 0.527000
# Epoch 29, CIFAR-10 Batch 2:  Loss:    1.2619 Validation Accuracy: 0.511600
# Epoch 29, CIFAR-10 Batch 3:  Loss:    1.0731 Validation Accuracy: 0.523000
# Epoch 29, CIFAR-10 Batch 4:  Loss:    1.2034 Validation Accuracy: 0.525200
# Epoch 29, CIFAR-10 Batch 5:  Loss:    1.4185 Validation Accuracy: 0.521200
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.4502 Validation Accuracy: 0.535600
# Epoch 30, CIFAR-10 Batch 2:  Loss:    1.2515 Validation Accuracy: 0.524200
# Epoch 30, CIFAR-10 Batch 3:  Loss:    1.0955 Validation Accuracy: 0.510400
# Epoch 30, CIFAR-10 Batch 4:  Loss:    1.1971 Validation Accuracy: 0.519200
# Epoch 30, CIFAR-10 Batch 5:  Loss:    1.3852 Validation Accuracy: 0.519400
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.4253 Validation Accuracy: 0.530400
# Epoch 31, CIFAR-10 Batch 2:  Loss:    1.2085 Validation Accuracy: 0.522600
# Epoch 31, CIFAR-10 Batch 3:  Loss:    1.0717 Validation Accuracy: 0.522600
# Epoch 31, CIFAR-10 Batch 4:  Loss:    1.1602 Validation Accuracy: 0.523400
# Epoch 31, CIFAR-10 Batch 5:  Loss:    1.3727 Validation Accuracy: 0.529000
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.4218 Validation Accuracy: 0.534600
# Epoch 32, CIFAR-10 Batch 2:  Loss:    1.2582 Validation Accuracy: 0.516600
# Epoch 32, CIFAR-10 Batch 3:  Loss:    1.0626 Validation Accuracy: 0.521600
# Epoch 32, CIFAR-10 Batch 4:  Loss:    1.1534 Validation Accuracy: 0.532200
# Epoch 32, CIFAR-10 Batch 5:  Loss:    1.3518 Validation Accuracy: 0.530000
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.4526 Validation Accuracy: 0.530600
# Epoch 33, CIFAR-10 Batch 2:  Loss:    1.2150 Validation Accuracy: 0.527000
# Epoch 33, CIFAR-10 Batch 3:  Loss:    1.0434 Validation Accuracy: 0.516600
# Epoch 33, CIFAR-10 Batch 4:  Loss:    1.1692 Validation Accuracy: 0.529600
# Epoch 33, CIFAR-10 Batch 5:  Loss:    1.3239 Validation Accuracy: 0.533200
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.4082 Validation Accuracy: 0.525800
# Epoch 34, CIFAR-10 Batch 2:  Loss:    1.2447 Validation Accuracy: 0.523000
# Epoch 34, CIFAR-10 Batch 3:  Loss:    1.0476 Validation Accuracy: 0.528600
# Epoch 34, CIFAR-10 Batch 4:  Loss:    1.1496 Validation Accuracy: 0.528800
# Epoch 34, CIFAR-10 Batch 5:  Loss:    1.3421 Validation Accuracy: 0.531400
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.4318 Validation Accuracy: 0.530800
# Epoch 35, CIFAR-10 Batch 2:  Loss:    1.2399 Validation Accuracy: 0.531000
# Epoch 35, CIFAR-10 Batch 3:  Loss:    1.0343 Validation Accuracy: 0.530400
# Epoch 35, CIFAR-10 Batch 4:  Loss:    1.1712 Validation Accuracy: 0.526800
# Epoch 35, CIFAR-10 Batch 5:  Loss:    1.3408 Validation Accuracy: 0.537000
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.3690 Validation Accuracy: 0.533800
# Epoch 36, CIFAR-10 Batch 2:  Loss:    1.2088 Validation Accuracy: 0.527800
# Epoch 36, CIFAR-10 Batch 3:  Loss:    1.0389 Validation Accuracy: 0.513200
# Epoch 36, CIFAR-10 Batch 4:  Loss:    1.1593 Validation Accuracy: 0.527000
# Epoch 36, CIFAR-10 Batch 5:  Loss:    1.3889 Validation Accuracy: 0.516400
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.4096 Validation Accuracy: 0.526000
# Epoch 37, CIFAR-10 Batch 2:  Loss:    1.1768 Validation Accuracy: 0.526400
# Epoch 37, CIFAR-10 Batch 3:  Loss:    1.0417 Validation Accuracy: 0.538000
# Epoch 37, CIFAR-10 Batch 4:  Loss:    1.1391 Validation Accuracy: 0.535000
# Epoch 37, CIFAR-10 Batch 5:  Loss:    1.3424 Validation Accuracy: 0.528600
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.4413 Validation Accuracy: 0.519400
# Epoch 38, CIFAR-10 Batch 2:  Loss:    1.1893 Validation Accuracy: 0.534000
# Epoch 38, CIFAR-10 Batch 3:  Loss:    1.0223 Validation Accuracy: 0.534200
# Epoch 38, CIFAR-10 Batch 4:  Loss:    1.1501 Validation Accuracy: 0.534200
# Epoch 38, CIFAR-10 Batch 5:  Loss:    1.3605 Validation Accuracy: 0.525800
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.3963 Validation Accuracy: 0.529400
# Epoch 39, CIFAR-10 Batch 2:  Loss:    1.1663 Validation Accuracy: 0.532000
# Epoch 39, CIFAR-10 Batch 3:  Loss:    1.0379 Validation Accuracy: 0.525000
# Epoch 39, CIFAR-10 Batch 4:  Loss:    1.1174 Validation Accuracy: 0.534600
# Epoch 39, CIFAR-10 Batch 5:  Loss:    1.2799 Validation Accuracy: 0.530200
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.3511 Validation Accuracy: 0.528600
# Epoch 40, CIFAR-10 Batch 2:  Loss:    1.1987 Validation Accuracy: 0.521800
# Epoch 40, CIFAR-10 Batch 3:  Loss:    1.0383 Validation Accuracy: 0.535600
# Epoch 40, CIFAR-10 Batch 4:  Loss:    1.1411 Validation Accuracy: 0.531600
# Epoch 40, CIFAR-10 Batch 5:  Loss:    1.3195 Validation Accuracy: 0.529000
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.3743 Validation Accuracy: 0.531400
# Epoch 41, CIFAR-10 Batch 2:  Loss:    1.1635 Validation Accuracy: 0.519800
# Epoch 41, CIFAR-10 Batch 3:  Loss:    1.0371 Validation Accuracy: 0.539200
# Epoch 41, CIFAR-10 Batch 4:  Loss:    1.1543 Validation Accuracy: 0.518800
# Epoch 41, CIFAR-10 Batch 5:  Loss:    1.3263 Validation Accuracy: 0.526800
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.3640 Validation Accuracy: 0.527600
# Epoch 42, CIFAR-10 Batch 2:  Loss:    1.1529 Validation Accuracy: 0.542200
# Epoch 42, CIFAR-10 Batch 3:  Loss:    1.0168 Validation Accuracy: 0.539400
# Epoch 42, CIFAR-10 Batch 4:  Loss:    1.1470 Validation Accuracy: 0.526400
# Epoch 42, CIFAR-10 Batch 5:  Loss:    1.3039 Validation Accuracy: 0.528200
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.3622 Validation Accuracy: 0.537000
# Epoch 43, CIFAR-10 Batch 2:  Loss:    1.1589 Validation Accuracy: 0.519600
# Epoch 43, CIFAR-10 Batch 3:  Loss:    1.0382 Validation Accuracy: 0.533400
# Epoch 43, CIFAR-10 Batch 4:  Loss:    1.1438 Validation Accuracy: 0.532000
# Epoch 43, CIFAR-10 Batch 5:  Loss:    1.3140 Validation Accuracy: 0.532000
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.3872 Validation Accuracy: 0.541400
# Epoch 44, CIFAR-10 Batch 2:  Loss:    1.1404 Validation Accuracy: 0.520400
# Epoch 44, CIFAR-10 Batch 3:  Loss:    1.0060 Validation Accuracy: 0.536200
# Epoch 44, CIFAR-10 Batch 4:  Loss:    1.1266 Validation Accuracy: 0.537200
# Epoch 44, CIFAR-10 Batch 5:  Loss:    1.2914 Validation Accuracy: 0.533400
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.3454 Validation Accuracy: 0.528600
# Epoch 45, CIFAR-10 Batch 2:  Loss:    1.1221 Validation Accuracy: 0.541400
# Epoch 45, CIFAR-10 Batch 3:  Loss:    1.0108 Validation Accuracy: 0.541200
# Epoch 45, CIFAR-10 Batch 4:  Loss:    1.1155 Validation Accuracy: 0.539600
# Epoch 45, CIFAR-10 Batch 5:  Loss:    1.2805 Validation Accuracy: 0.536600
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.3031 Validation Accuracy: 0.536000
# Epoch 46, CIFAR-10 Batch 2:  Loss:    1.0831 Validation Accuracy: 0.538600
# Epoch 46, CIFAR-10 Batch 3:  Loss:    0.9927 Validation Accuracy: 0.528200
# Epoch 46, CIFAR-10 Batch 4:  Loss:    1.1093 Validation Accuracy: 0.532200
# Epoch 46, CIFAR-10 Batch 5:  Loss:    1.2832 Validation Accuracy: 0.535000
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.3942 Validation Accuracy: 0.542400
# Epoch 47, CIFAR-10 Batch 2:  Loss:    1.1546 Validation Accuracy: 0.536600
# Epoch 47, CIFAR-10 Batch 3:  Loss:    0.9802 Validation Accuracy: 0.540600
# Epoch 47, CIFAR-10 Batch 4:  Loss:    1.1083 Validation Accuracy: 0.533600
# Epoch 47, CIFAR-10 Batch 5:  Loss:    1.2802 Validation Accuracy: 0.534800
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.3537 Validation Accuracy: 0.533000
# Epoch 48, CIFAR-10 Batch 2:  Loss:    1.1165 Validation Accuracy: 0.537400
# Epoch 48, CIFAR-10 Batch 3:  Loss:    0.9759 Validation Accuracy: 0.533600
# Epoch 48, CIFAR-10 Batch 4:  Loss:    1.1110 Validation Accuracy: 0.536200
# Epoch 48, CIFAR-10 Batch 5:  Loss:    1.2535 Validation Accuracy: 0.530400
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.3980 Validation Accuracy: 0.534400
# Epoch 49, CIFAR-10 Batch 2:  Loss:    1.1274 Validation Accuracy: 0.538200
# Epoch 49, CIFAR-10 Batch 3:  Loss:    0.9979 Validation Accuracy: 0.527400
# Epoch 49, CIFAR-10 Batch 4:  Loss:    1.0567 Validation Accuracy: 0.541600
# Epoch 49, CIFAR-10 Batch 5:  Loss:    1.2542 Validation Accuracy: 0.536600
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.3116 Validation Accuracy: 0.536400
# Epoch 50, CIFAR-10 Batch 2:  Loss:    1.0851 Validation Accuracy: 0.544800
# Epoch 50, CIFAR-10 Batch 3:  Loss:    0.9728 Validation Accuracy: 0.529800
# Epoch 50, CIFAR-10 Batch 4:  Loss:    1.0850 Validation Accuracy: 0.537400
# Epoch 50, CIFAR-10 Batch 5:  Loss:    1.2554 Validation Accuracy: 0.535200
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.3247 Validation Accuracy: 0.531200
# Epoch 51, CIFAR-10 Batch 2:  Loss:    1.1371 Validation Accuracy: 0.530200
# Epoch 51, CIFAR-10 Batch 3:  Loss:    0.9846 Validation Accuracy: 0.534600
# Epoch 51, CIFAR-10 Batch 4:  Loss:    1.0893 Validation Accuracy: 0.547000
# Epoch 51, CIFAR-10 Batch 5:  Loss:    1.2191 Validation Accuracy: 0.540000
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.3383 Validation Accuracy: 0.538800
# Epoch 52, CIFAR-10 Batch 2:  Loss:    1.1083 Validation Accuracy: 0.542000
# Epoch 52, CIFAR-10 Batch 3:  Loss:    0.9628 Validation Accuracy: 0.537000
# Epoch 52, CIFAR-10 Batch 4:  Loss:    1.0806 Validation Accuracy: 0.543200
# Epoch 52, CIFAR-10 Batch 5:  Loss:    1.2332 Validation Accuracy: 0.537800
# Epoch 53, CIFAR-10 Batch 1:  Loss:    1.3308 Validation Accuracy: 0.534800
# Epoch 53, CIFAR-10 Batch 2:  Loss:    1.0688 Validation Accuracy: 0.543600
# Epoch 53, CIFAR-10 Batch 3:  Loss:    0.9835 Validation Accuracy: 0.537000
# Epoch 53, CIFAR-10 Batch 4:  Loss:    1.0585 Validation Accuracy: 0.541000
# Epoch 53, CIFAR-10 Batch 5:  Loss:    1.2324 Validation Accuracy: 0.533800
# Epoch 54, CIFAR-10 Batch 1:  Loss:    1.3184 Validation Accuracy: 0.534800
# Epoch 54, CIFAR-10 Batch 2:  Loss:    1.0627 Validation Accuracy: 0.537400
# Epoch 54, CIFAR-10 Batch 3:  Loss:    1.0185 Validation Accuracy: 0.540000
# Epoch 54, CIFAR-10 Batch 4:  Loss:    1.0348 Validation Accuracy: 0.536000
# Epoch 54, CIFAR-10 Batch 5:  Loss:    1.2639 Validation Accuracy: 0.541600
# Epoch 55, CIFAR-10 Batch 1:  Loss:    1.2811 Validation Accuracy: 0.534600
# Epoch 55, CIFAR-10 Batch 2:  Loss:    1.0826 Validation Accuracy: 0.533800
# Epoch 55, CIFAR-10 Batch 3:  Loss:    0.9645 Validation Accuracy: 0.541200
# Epoch 55, CIFAR-10 Batch 4:  Loss:    1.0785 Validation Accuracy: 0.541800
# Epoch 55, CIFAR-10 Batch 5:  Loss:    1.2381 Validation Accuracy: 0.534800
# Epoch 56, CIFAR-10 Batch 1:  Loss:    1.3098 Validation Accuracy: 0.531800
# Epoch 56, CIFAR-10 Batch 2:  Loss:    1.0688 Validation Accuracy: 0.538600
# Epoch 56, CIFAR-10 Batch 3:  Loss:    0.9733 Validation Accuracy: 0.540200
# Epoch 56, CIFAR-10 Batch 4:  Loss:    1.0541 Validation Accuracy: 0.540800
# Epoch 56, CIFAR-10 Batch 5:  Loss:    1.2224 Validation Accuracy: 0.532800
# Epoch 57, CIFAR-10 Batch 1:  Loss:    1.2814 Validation Accuracy: 0.542200
# Epoch 57, CIFAR-10 Batch 2:  Loss:    1.0745 Validation Accuracy: 0.530600
# Epoch 57, CIFAR-10 Batch 3:  Loss:    0.9862 Validation Accuracy: 0.531600
# Epoch 57, CIFAR-10 Batch 4:  Loss:    1.0652 Validation Accuracy: 0.534800
# Epoch 57, CIFAR-10 Batch 5:  Loss:    1.2194 Validation Accuracy: 0.534400
# Epoch 58, CIFAR-10 Batch 1:  Loss:    1.3206 Validation Accuracy: 0.539600
# Epoch 58, CIFAR-10 Batch 2:  Loss:    1.0293 Validation Accuracy: 0.541600
# Epoch 58, CIFAR-10 Batch 3:  Loss:    0.9504 Validation Accuracy: 0.534600
# Epoch 58, CIFAR-10 Batch 4:  Loss:    1.0600 Validation Accuracy: 0.535800
# Epoch 58, CIFAR-10 Batch 5:  Loss:    1.2152 Validation Accuracy: 0.544600
# Epoch 59, CIFAR-10 Batch 1:  Loss:    1.3164 Validation Accuracy: 0.545000
# Epoch 59, CIFAR-10 Batch 2:  Loss:    1.0469 Validation Accuracy: 0.541000
# Epoch 59, CIFAR-10 Batch 3:  Loss:    0.9734 Validation Accuracy: 0.549400
# Epoch 59, CIFAR-10 Batch 4:  Loss:    1.0586 Validation Accuracy: 0.545000
# Epoch 59, CIFAR-10 Batch 5:  Loss:    1.1929 Validation Accuracy: 0.540800
# Epoch 60, CIFAR-10 Batch 1:  Loss:    1.3420 Validation Accuracy: 0.529600
# Epoch 60, CIFAR-10 Batch 2:  Loss:    1.0258 Validation Accuracy: 0.542600
# Epoch 60, CIFAR-10 Batch 3:  Loss:    0.9467 Validation Accuracy: 0.538600
# Epoch 60, CIFAR-10 Batch 4:  Loss:    1.0996 Validation Accuracy: 0.530200
# Epoch 60, CIFAR-10 Batch 5:  Loss:    1.1730 Validation Accuracy: 0.532000
# Epoch 61, CIFAR-10 Batch 1:  Loss:    1.2743 Validation Accuracy: 0.540400
# Epoch 61, CIFAR-10 Batch 2:  Loss:    1.0376 Validation Accuracy: 0.537000
# Epoch 61, CIFAR-10 Batch 3:  Loss:    0.9643 Validation Accuracy: 0.536400
# Epoch 61, CIFAR-10 Batch 4:  Loss:    1.0461 Validation Accuracy: 0.546400
# Epoch 61, CIFAR-10 Batch 5:  Loss:    1.1996 Validation Accuracy: 0.538200
# Epoch 62, CIFAR-10 Batch 1:  Loss:    1.2690 Validation Accuracy: 0.533000
# Epoch 62, CIFAR-10 Batch 2:  Loss:    1.0392 Validation Accuracy: 0.536400
# Epoch 62, CIFAR-10 Batch 3:  Loss:    1.0009 Validation Accuracy: 0.543800
# Epoch 62, CIFAR-10 Batch 4:  Loss:    1.0492 Validation Accuracy: 0.539800
# Epoch 62, CIFAR-10 Batch 5:  Loss:    1.1914 Validation Accuracy: 0.535000
# Epoch 63, CIFAR-10 Batch 1:  Loss:    1.2441 Validation Accuracy: 0.536800
# Epoch 63, CIFAR-10 Batch 2:  Loss:    1.0386 Validation Accuracy: 0.540000
# Epoch 63, CIFAR-10 Batch 3:  Loss:    0.9641 Validation Accuracy: 0.543600
# Epoch 63, CIFAR-10 Batch 4:  Loss:    1.0205 Validation Accuracy: 0.540000
# Epoch 63, CIFAR-10 Batch 5:  Loss:    1.1763 Validation Accuracy: 0.539200
# Epoch 64, CIFAR-10 Batch 1:  Loss:    1.2972 Validation Accuracy: 0.541600
# Epoch 64, CIFAR-10 Batch 2:  Loss:    1.0754 Validation Accuracy: 0.536400
# Epoch 64, CIFAR-10 Batch 3:  Loss:    0.9384 Validation Accuracy: 0.551400
# Epoch 64, CIFAR-10 Batch 4:  Loss:    1.0642 Validation Accuracy: 0.535600
# Epoch 64, CIFAR-10 Batch 5:  Loss:    1.2054 Validation Accuracy: 0.538400
# Epoch 65, CIFAR-10 Batch 1:  Loss:    1.2567 Validation Accuracy: 0.543000
# Epoch 65, CIFAR-10 Batch 2:  Loss:    1.0321 Validation Accuracy: 0.547600
# Epoch 65, CIFAR-10 Batch 3:  Loss:    0.9362 Validation Accuracy: 0.530800
# Epoch 65, CIFAR-10 Batch 4:  Loss:    1.0214 Validation Accuracy: 0.544000
# Epoch 65, CIFAR-10 Batch 5:  Loss:    1.1963 Validation Accuracy: 0.540000
# Epoch 66, CIFAR-10 Batch 1:  Loss:    1.2592 Validation Accuracy: 0.541800
# Epoch 66, CIFAR-10 Batch 2:  Loss:    1.0653 Validation Accuracy: 0.539200
# Epoch 66, CIFAR-10 Batch 3:  Loss:    0.9349 Validation Accuracy: 0.548400
# Epoch 66, CIFAR-10 Batch 4:  Loss:    1.0499 Validation Accuracy: 0.536200
# Epoch 66, CIFAR-10 Batch 5:  Loss:    1.1640 Validation Accuracy: 0.539600
# Epoch 67, CIFAR-10 Batch 1:  Loss:    1.2542 Validation Accuracy: 0.538800
# Epoch 67, CIFAR-10 Batch 2:  Loss:    1.0246 Validation Accuracy: 0.547400
# Epoch 67, CIFAR-10 Batch 3:  Loss:    0.9261 Validation Accuracy: 0.544200
# Epoch 67, CIFAR-10 Batch 4:  Loss:    1.0723 Validation Accuracy: 0.541800
# Epoch 67, CIFAR-10 Batch 5:  Loss:    1.2070 Validation Accuracy: 0.540800
# Epoch 68, CIFAR-10 Batch 1:  Loss:    1.2770 Validation Accuracy: 0.540400
# Epoch 68, CIFAR-10 Batch 2:  Loss:    1.0373 Validation Accuracy: 0.535200
# Epoch 68, CIFAR-10 Batch 3:  Loss:    0.9585 Validation Accuracy: 0.526000
# Epoch 68, CIFAR-10 Batch 4:  Loss:    1.0199 Validation Accuracy: 0.539000
# Epoch 68, CIFAR-10 Batch 5:  Loss:    1.1563 Validation Accuracy: 0.535400
# Epoch 69, CIFAR-10 Batch 1:  Loss:    1.2753 Validation Accuracy: 0.542800
# Epoch 69, CIFAR-10 Batch 2:  Loss:    1.0523 Validation Accuracy: 0.549200
# Epoch 69, CIFAR-10 Batch 3:  Loss:    0.8936 Validation Accuracy: 0.543200
# Epoch 69, CIFAR-10 Batch 4:  Loss:    1.0412 Validation Accuracy: 0.533200
# Epoch 69, CIFAR-10 Batch 5:  Loss:    1.1511 Validation Accuracy: 0.540200
# Epoch 70, CIFAR-10 Batch 1:  Loss:    1.2133 Validation Accuracy: 0.547600
# Epoch 70, CIFAR-10 Batch 2:  Loss:    1.0198 Validation Accuracy: 0.541800
# Epoch 70, CIFAR-10 Batch 3:  Loss:    0.9123 Validation Accuracy: 0.536600
# Epoch 70, CIFAR-10 Batch 4:  Loss:    1.0471 Validation Accuracy: 0.545200
# Epoch 70, CIFAR-10 Batch 5:  Loss:    1.1617 Validation Accuracy: 0.538200
# Epoch 71, CIFAR-10 Batch 1:  Loss:    1.2329 Validation Accuracy: 0.545400
# Epoch 71, CIFAR-10 Batch 2:  Loss:    1.0109 Validation Accuracy: 0.547000
# Epoch 71, CIFAR-10 Batch 3:  Loss:    0.9278 Validation Accuracy: 0.551400
# Epoch 71, CIFAR-10 Batch 4:  Loss:    1.0403 Validation Accuracy: 0.538600
# Epoch 71, CIFAR-10 Batch 5:  Loss:    1.1611 Validation Accuracy: 0.539000
# Epoch 72, CIFAR-10 Batch 1:  Loss:    1.2182 Validation Accuracy: 0.540600
# Epoch 72, CIFAR-10 Batch 2:  Loss:    1.0215 Validation Accuracy: 0.537600
# Epoch 72, CIFAR-10 Batch 3:  Loss:    0.9212 Validation Accuracy: 0.545400
# Epoch 72, CIFAR-10 Batch 4:  Loss:    1.0134 Validation Accuracy: 0.545800
# Epoch 72, CIFAR-10 Batch 5:  Loss:    1.1608 Validation Accuracy: 0.543800
# Epoch 73, CIFAR-10 Batch 1:  Loss:    1.2707 Validation Accuracy: 0.541000
# Epoch 73, CIFAR-10 Batch 2:  Loss:    1.0113 Validation Accuracy: 0.542000
# Epoch 73, CIFAR-10 Batch 3:  Loss:    0.9215 Validation Accuracy: 0.547000
# Epoch 73, CIFAR-10 Batch 4:  Loss:    1.0042 Validation Accuracy: 0.537600
# Epoch 73, CIFAR-10 Batch 5:  Loss:    1.1501 Validation Accuracy: 0.539000
# Epoch 74, CIFAR-10 Batch 1:  Loss:    1.2053 Validation Accuracy: 0.543200
# Epoch 74, CIFAR-10 Batch 2:  Loss:    1.0159 Validation Accuracy: 0.537800
# Epoch 74, CIFAR-10 Batch 3:  Loss:    0.9370 Validation Accuracy: 0.542400
# Epoch 74, CIFAR-10 Batch 4:  Loss:    1.0159 Validation Accuracy: 0.546200
# Epoch 74, CIFAR-10 Batch 5:  Loss:    1.1419 Validation Accuracy: 0.537000
# Epoch 75, CIFAR-10 Batch 1:  Loss:    1.2211 Validation Accuracy: 0.535800
# Epoch 75, CIFAR-10 Batch 2:  Loss:    1.0066 Validation Accuracy: 0.537000
# Epoch 75, CIFAR-10 Batch 3:  Loss:    0.9286 Validation Accuracy: 0.535600
# Epoch 75, CIFAR-10 Batch 4:  Loss:    0.9794 Validation Accuracy: 0.550200
# Epoch 75, CIFAR-10 Batch 5:  Loss:    1.1230 Validation Accuracy: 0.541000
# Epoch 76, CIFAR-10 Batch 1:  Loss:    1.2386 Validation Accuracy: 0.553000
# Epoch 76, CIFAR-10 Batch 2:  Loss:    1.0290 Validation Accuracy: 0.544000
# Epoch 76, CIFAR-10 Batch 3:  Loss:    0.9095 Validation Accuracy: 0.552600
# Epoch 76, CIFAR-10 Batch 4:  Loss:    1.0113 Validation Accuracy: 0.535600
# Epoch 76, CIFAR-10 Batch 5:  Loss:    1.1316 Validation Accuracy: 0.535800
# Epoch 77, CIFAR-10 Batch 1:  Loss:    1.1563 Validation Accuracy: 0.543000
# Epoch 77, CIFAR-10 Batch 2:  Loss:    1.0161 Validation Accuracy: 0.550400
# Epoch 77, CIFAR-10 Batch 3:  Loss:    0.9426 Validation Accuracy: 0.529800
# Epoch 77, CIFAR-10 Batch 4:  Loss:    1.0212 Validation Accuracy: 0.548000
# Epoch 77, CIFAR-10 Batch 5:  Loss:    1.1414 Validation Accuracy: 0.536800
# Epoch 78, CIFAR-10 Batch 1:  Loss:    1.2290 Validation Accuracy: 0.547400
# Epoch 78, CIFAR-10 Batch 2:  Loss:    1.0067 Validation Accuracy: 0.544800
# Epoch 78, CIFAR-10 Batch 3:  Loss:    0.9193 Validation Accuracy: 0.550800
# Epoch 78, CIFAR-10 Batch 4:  Loss:    1.0341 Validation Accuracy: 0.524600
# Epoch 78, CIFAR-10 Batch 5:  Loss:    1.1252 Validation Accuracy: 0.542600
# Epoch 79, CIFAR-10 Batch 1:  Loss:    1.1890 Validation Accuracy: 0.544000
# Epoch 79, CIFAR-10 Batch 2:  Loss:    1.0089 Validation Accuracy: 0.542800
# Epoch 79, CIFAR-10 Batch 3:  Loss:    0.9069 Validation Accuracy: 0.538200
# Epoch 79, CIFAR-10 Batch 4:  Loss:    0.9966 Validation Accuracy: 0.538600
# Epoch 79, CIFAR-10 Batch 5:  Loss:    1.1002 Validation Accuracy: 0.544800
# Epoch 80, CIFAR-10 Batch 1:  Loss:    1.2204 Validation Accuracy: 0.537200
# Epoch 80, CIFAR-10 Batch 2:  Loss:    1.0031 Validation Accuracy: 0.552600
# Epoch 80, CIFAR-10 Batch 3:  Loss:    0.9089 Validation Accuracy: 0.546000
# Epoch 80, CIFAR-10 Batch 4:  Loss:    1.0207 Validation Accuracy: 0.538000
# Epoch 80, CIFAR-10 Batch 5:  Loss:    1.1155 Validation Accuracy: 0.544400
# Epoch 81, CIFAR-10 Batch 1:  Loss:    1.1780 Validation Accuracy: 0.546600
# Epoch 81, CIFAR-10 Batch 2:  Loss:    0.9751 Validation Accuracy: 0.549800
# Epoch 81, CIFAR-10 Batch 3:  Loss:    0.9598 Validation Accuracy: 0.548000
# Epoch 81, CIFAR-10 Batch 4:  Loss:    1.0029 Validation Accuracy: 0.536000
# Epoch 81, CIFAR-10 Batch 5:  Loss:    1.1399 Validation Accuracy: 0.537400
# Epoch 82, CIFAR-10 Batch 1:  Loss:    1.2182 Validation Accuracy: 0.548800
# Epoch 82, CIFAR-10 Batch 2:  Loss:    0.9764 Validation Accuracy: 0.546400
# Epoch 82, CIFAR-10 Batch 3:  Loss:    0.9726 Validation Accuracy: 0.553200
# Epoch 82, CIFAR-10 Batch 4:  Loss:    0.9818 Validation Accuracy: 0.544600
# Epoch 82, CIFAR-10 Batch 5:  Loss:    1.1107 Validation Accuracy: 0.542400
# Epoch 83, CIFAR-10 Batch 1:  Loss:    1.2259 Validation Accuracy: 0.553000
# Epoch 83, CIFAR-10 Batch 2:  Loss:    0.9852 Validation Accuracy: 0.549600
# Epoch 83, CIFAR-10 Batch 3:  Loss:    0.8909 Validation Accuracy: 0.540600
# Epoch 83, CIFAR-10 Batch 4:  Loss:    0.9657 Validation Accuracy: 0.544400
# Epoch 83, CIFAR-10 Batch 5:  Loss:    1.1340 Validation Accuracy: 0.532800
# Epoch 84, CIFAR-10 Batch 1:  Loss:    1.1601 Validation Accuracy: 0.547800
# Epoch 84, CIFAR-10 Batch 2:  Loss:    0.9964 Validation Accuracy: 0.542600
# Epoch 84, CIFAR-10 Batch 3:  Loss:    0.9442 Validation Accuracy: 0.538400
# Epoch 84, CIFAR-10 Batch 4:  Loss:    0.9995 Validation Accuracy: 0.545600
# Epoch 84, CIFAR-10 Batch 5:  Loss:    1.1653 Validation Accuracy: 0.530600
# Epoch 85, CIFAR-10 Batch 1:  Loss:    1.1759 Validation Accuracy: 0.548000
# Epoch 85, CIFAR-10 Batch 2:  Loss:    0.9756 Validation Accuracy: 0.552800
# Epoch 85, CIFAR-10 Batch 3:  Loss:    0.9405 Validation Accuracy: 0.537400
# Epoch 85, CIFAR-10 Batch 4:  Loss:    0.9718 Validation Accuracy: 0.545200
# Epoch 85, CIFAR-10 Batch 5:  Loss:    1.1209 Validation Accuracy: 0.539800
# Epoch 86, CIFAR-10 Batch 1:  Loss:    1.1630 Validation Accuracy: 0.543200
# Epoch 86, CIFAR-10 Batch 2:  Loss:    0.9635 Validation Accuracy: 0.553400
# Epoch 86, CIFAR-10 Batch 3:  Loss:    0.8785 Validation Accuracy: 0.550200
# Epoch 86, CIFAR-10 Batch 4:  Loss:    1.0054 Validation Accuracy: 0.544400
# Epoch 86, CIFAR-10 Batch 5:  Loss:    1.1194 Validation Accuracy: 0.532800
# Epoch 87, CIFAR-10 Batch 1:  Loss:    1.1612 Validation Accuracy: 0.548000
# Epoch 87, CIFAR-10 Batch 2:  Loss:    0.9302 Validation Accuracy: 0.548800
# Epoch 87, CIFAR-10 Batch 3:  Loss:    0.8948 Validation Accuracy: 0.555800
# Epoch 87, CIFAR-10 Batch 4:  Loss:    0.9949 Validation Accuracy: 0.536400
# Epoch 87, CIFAR-10 Batch 5:  Loss:    1.1334 Validation Accuracy: 0.534200
# Epoch 88, CIFAR-10 Batch 1:  Loss:    1.1541 Validation Accuracy: 0.550800
# Epoch 88, CIFAR-10 Batch 2:  Loss:    0.9723 Validation Accuracy: 0.542400
# Epoch 88, CIFAR-10 Batch 3:  Loss:    0.8933 Validation Accuracy: 0.546400
# Epoch 88, CIFAR-10 Batch 4:  Loss:    1.0596 Validation Accuracy: 0.534000
# Epoch 88, CIFAR-10 Batch 5:  Loss:    1.1066 Validation Accuracy: 0.540000
# Epoch 89, CIFAR-10 Batch 1:  Loss:    1.1782 Validation Accuracy: 0.547800
# Epoch 89, CIFAR-10 Batch 2:  Loss:    0.9523 Validation Accuracy: 0.548400
# Epoch 89, CIFAR-10 Batch 3:  Loss:    0.8655 Validation Accuracy: 0.552200
# Epoch 89, CIFAR-10 Batch 4:  Loss:    0.9857 Validation Accuracy: 0.540800
# Epoch 89, CIFAR-10 Batch 5:  Loss:    1.0528 Validation Accuracy: 0.545000
# Epoch 90, CIFAR-10 Batch 1:  Loss:    1.1467 Validation Accuracy: 0.550400
# Epoch 90, CIFAR-10 Batch 2:  Loss:    1.0252 Validation Accuracy: 0.547200
# Epoch 90, CIFAR-10 Batch 3:  Loss:    0.8670 Validation Accuracy: 0.555200
# Epoch 90, CIFAR-10 Batch 4:  Loss:    0.9294 Validation Accuracy: 0.546200
# Epoch 90, CIFAR-10 Batch 5:  Loss:    1.0885 Validation Accuracy: 0.546600
# Epoch 91, CIFAR-10 Batch 1:  Loss:    1.1541 Validation Accuracy: 0.551000
# Epoch 91, CIFAR-10 Batch 2:  Loss:    0.9534 Validation Accuracy: 0.548800
# Epoch 91, CIFAR-10 Batch 3:  Loss:    0.8847 Validation Accuracy: 0.545600
# Epoch 91, CIFAR-10 Batch 4:  Loss:    1.0316 Validation Accuracy: 0.545000
# Epoch 91, CIFAR-10 Batch 5:  Loss:    1.1042 Validation Accuracy: 0.547400
# Epoch 92, CIFAR-10 Batch 1:  Loss:    1.1304 Validation Accuracy: 0.548800
# Epoch 92, CIFAR-10 Batch 2:  Loss:    0.9324 Validation Accuracy: 0.539600
# Epoch 92, CIFAR-10 Batch 3:  Loss:    0.9003 Validation Accuracy: 0.537000
# Epoch 92, CIFAR-10 Batch 4:  Loss:    0.9431 Validation Accuracy: 0.548000
# Epoch 92, CIFAR-10 Batch 5:  Loss:    1.1013 Validation Accuracy: 0.539400
# Epoch 93, CIFAR-10 Batch 1:  Loss:    1.1512 Validation Accuracy: 0.542400
# Epoch 93, CIFAR-10 Batch 2:  Loss:    0.9830 Validation Accuracy: 0.537400
# Epoch 93, CIFAR-10 Batch 3:  Loss:    0.9182 Validation Accuracy: 0.539600
# Epoch 93, CIFAR-10 Batch 4:  Loss:    0.9605 Validation Accuracy: 0.552000
# Epoch 93, CIFAR-10 Batch 5:  Loss:    1.0806 Validation Accuracy: 0.546800
# Epoch 94, CIFAR-10 Batch 1:  Loss:    1.1715 Validation Accuracy: 0.550200
# Epoch 94, CIFAR-10 Batch 2:  Loss:    0.9401 Validation Accuracy: 0.547800
# Epoch 94, CIFAR-10 Batch 3:  Loss:    0.8639 Validation Accuracy: 0.547400
# Epoch 94, CIFAR-10 Batch 4:  Loss:    0.9735 Validation Accuracy: 0.538200
# Epoch 94, CIFAR-10 Batch 5:  Loss:    1.1098 Validation Accuracy: 0.546200
# Epoch 95, CIFAR-10 Batch 1:  Loss:    1.1380 Validation Accuracy: 0.530600
# Epoch 95, CIFAR-10 Batch 2:  Loss:    0.9161 Validation Accuracy: 0.545600
# Epoch 95, CIFAR-10 Batch 3:  Loss:    0.8822 Validation Accuracy: 0.549800
# Epoch 95, CIFAR-10 Batch 4:  Loss:    0.9921 Validation Accuracy: 0.541000
# Epoch 95, CIFAR-10 Batch 5:  Loss:    1.0811 Validation Accuracy: 0.544400
# Epoch 96, CIFAR-10 Batch 1:  Loss:    1.1179 Validation Accuracy: 0.546400
# Epoch 96, CIFAR-10 Batch 2:  Loss:    0.9728 Validation Accuracy: 0.532400
# Epoch 96, CIFAR-10 Batch 3:  Loss:    0.8763 Validation Accuracy: 0.552000
# Epoch 96, CIFAR-10 Batch 4:  Loss:    0.9530 Validation Accuracy: 0.530200
# Epoch 96, CIFAR-10 Batch 5:  Loss:    1.0957 Validation Accuracy: 0.550600
# Epoch 97, CIFAR-10 Batch 1:  Loss:    1.1586 Validation Accuracy: 0.543600
# Epoch 97, CIFAR-10 Batch 2:  Loss:    0.9511 Validation Accuracy: 0.550000
# Epoch 97, CIFAR-10 Batch 3:  Loss:    0.8665 Validation Accuracy: 0.534200
# Epoch 97, CIFAR-10 Batch 4:  Loss:    0.9933 Validation Accuracy: 0.540000
# Epoch 97, CIFAR-10 Batch 5:  Loss:    1.0828 Validation Accuracy: 0.539400
# Epoch 98, CIFAR-10 Batch 1:  Loss:    1.1435 Validation Accuracy: 0.547400
# Epoch 98, CIFAR-10 Batch 2:  Loss:    0.9432 Validation Accuracy: 0.547200
# Epoch 98, CIFAR-10 Batch 3:  Loss:    0.8836 Validation Accuracy: 0.543400
# Epoch 98, CIFAR-10 Batch 4:  Loss:    0.9674 Validation Accuracy: 0.547600
# Epoch 98, CIFAR-10 Batch 5:  Loss:    1.1039 Validation Accuracy: 0.541600
# Epoch 99, CIFAR-10 Batch 1:  Loss:    1.1531 Validation Accuracy: 0.543200
# Epoch 99, CIFAR-10 Batch 2:  Loss:    0.9047 Validation Accuracy: 0.537400
# Epoch 99, CIFAR-10 Batch 3:  Loss:    0.8841 Validation Accuracy: 0.546000
# Epoch 99, CIFAR-10 Batch 4:  Loss:    1.0198 Validation Accuracy: 0.537200
# Epoch 99, CIFAR-10 Batch 5:  Loss:    1.0333 Validation Accuracy: 0.550400
# Epoch 100, CIFAR-10 Batch 1:  Loss:    1.1136 Validation Accuracy: 0.551200
# Epoch 100, CIFAR-10 Batch 2:  Loss:    0.9057 Validation Accuracy: 0.549600
# Epoch 100, CIFAR-10 Batch 3:  Loss:    0.8502 Validation Accuracy: 0.535800
# Epoch 100, CIFAR-10 Batch 4:  Loss:    0.9729 Validation Accuracy: 0.541400
# Epoch 100, CIFAR-10 Batch 5:  Loss:    1.0452 Validation Accuracy: 0.547000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5535996835443038

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
